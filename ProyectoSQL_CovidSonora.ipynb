# %%
import pandas as pd
import mysql.connector as msql
from mysql.connector import Error
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Para demostrar lo aprendido en la clase, en esta libreta se realizara la carga de informacion desde un archivo csv a la base de datos de tipo MySql.
#
# Primeramente, mi ambiente para desarrollar es WSL, el subsistema de linux usado desde Windows, para realizar la conexion con el servidor local fue necesario instalar MySql desde la terminal de ubuntu, para ello segui esta [guia: "How to install MySQL on WSL 2](https://pen-y-fan.github.io/2021/08/08/How-to-install-MySQL-on-WSL-2-Ubuntu/), es muy directa y saca del apuro, sobre todo lo relacionado con la primera corrida y el establecer la contraseña para el usuario base root.
#
# Ademas antes de empezar hay que inicializar el servidor, en nuestro caso con el siguiente comando:
# **mysql -u root -h 127.0.0.1 -p -P 3306**

# %% [markdown]
# # Coordenadas
# Una vez que ya tenemos el servidor corriendo, procedemos a obtener los datos desde github

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mcd-unison/ing-caract/main/ejemplos/mapas/python/municipios_latlon.csv')
df.head()
# Out:
#      MUNICIPIO    LATITUD   LONGITUD
# 0      ACONCHI  29.825420 -110.20840
# 1  AGUA PRIETA  31.330048 -109.54904
# 2       ALAMOS  27.026820 -108.92560
# 3        ALTAR  30.715070 -111.82135
# 4     ARIVECHI  29.078530 -109.19583

# %% [markdown]
# Primeramente establecemos la conexion, y procedemos a crear la base de datos en la que guardaremos las tablas necesaria para la creacion de nuestros mapas

# %%
try:
    conn = msql.connect(host='localhost', user='root', password= 'root' ) #Establecer conexion
    if conn.is_connected():
        cursor = conn.cursor()#Crear cursor
        cursor.execute("CREATE DATABASE sonora") #Ejecutar instruccion
        print("La base de datos sonora fue creada")
        #Normalmente aqui se cierra el conector pero lo usaremos mas adelante en la libreta
except Error as e:
    print("Error al conectarse: ", e)
# Out:
# Error al conectarse:  1007 (HY000): Can't create database 'sonora'; database exists

# %%
df.dtypes
# Out:
# MUNICIPIO     object
# LATITUD      float64
# LONGITUD     float64
# dtype: object

# %% [markdown]
# Con la base de datos ya creada procedemos a crear la tabla que contendra las coordenadas de los municipios de Sonora

# %%
try:
    conn = msql.connect(host='localhost',
                           database='sonora', user='root',
                           password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("Estas coenctado a: ", record)
        cursor.execute('DROP TABLE IF EXISTS coordenada;')#Si existe una tabla con este nombre la borramos
        print('Creado tabla coordenada...')#Creacion de tabla con tipos y restricciones de datos
        cursor.execute(f"""CREATE TABLE coordenada (municipio CHAR(100) 
                        NOT NULL, latitud FLOAT(9,6) NOT NULL, 
                        longitud FLOAT(9,6) NOT NULL)""")
        print("La tabla coordenada fue creada...")
        for i,row in df.iterrows():#Insercion de valores
            sql = "INSERT INTO sonora.coordenada VALUES (%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            #La conexion no confirma los cambios en automatico por default, por lo que debemos correr el siguiente comando
            conn.commit()
        print('Operacion exitosa')
except Error as e:
    print("Error al conectarse: ", e)
# Out:
# Estas coenctado a:  ('sonora',)
# Creado tabla coordenada...
# La tabla coordenada fue creada...
# Operacion exitosa

# %%
# Corremos un query
sql = "SELECT * FROM coordenada"
cursor.execute(sql)
# Jalar todos los resultados
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# ('ACONCHI', 29.82542, -110.208397)
# ('AGUA PRIETA', 31.330048, -109.549042)
# ('ALAMOS', 27.026819, -108.925598)
# ('ALTAR', 30.715071, -111.82135)
# ('ARIVECHI', 29.078529, -109.195831)
# ('ARIZPE', 30.40764, -110.164749)
# ('ATIL', 30.884211, -111.582779)
# ('BACADEHUACHI', 29.81189, -109.140793)
# ('BACANORA', 28.98597, -109.400398)
# ('BACERAC', 30.50449, -108.924011)
# ('BACOACHI', 30.633801, -109.968391)
# ('BACUM', 27.55286, -110.0821)
# ('BANAMICHI', 30.00947, -110.213371)
# ('BAVIACORA', 29.71299, -110.161568)
# ('BAVISPE', 30.480261, -108.940491)
# ('BENITO JUAREZ', 27.116699, -109.833298)
# ('BENJAMIN HILL', 30.16931, -111.115051)
# ('CABORCA', 30.714491, -112.161087)
# ('CAJEME', 27.4974, -109.91124)
# ('CANANEA', 30.989941, -110.289169)
# ('CARBO', 29.68442, -110.956177)
# ('CUCURPE', 30.33173, -110.701332)
# ('CUMPAS', 29.99502, -109.780388)
# ('DIVISADEROS', 29.614441, -109.470093)
# ('EMPALME', 27.966631, -110.813652)
# ('ETCHOJOA', 26.91144, -109.626701)
# ('FRONTERAS', 30.89702, -109.558647)
# ('GENERAL PLUTARCO ELIAS CALLES', 31.86326, -112.84874)
# ('GRANADOS', 29.861601, -109.310432)
# ('GUAYMAS', 27.917891, -110.908928)
# ('HERMOSILLO', 29.08919, -110.961327)
# ('HUACHINERA', 30.207939, -108.959961)
# ('HUASABAS', 29.90736, -109.299988)
# ('HUATABAMPO', 26.82725, -109.641937)
# ('HUEPAC', 29.911039, -110.213539)
# ('IMURIS', 30.78964, -110.84494)
# ('LA COLORADA', 28.802839, -110.579399)
# ('MAGDALENA', 30.625031, -110.971397)
# ('MAZATAN', 29.0056, -110.137001)
# ('MOCTEZUMA', 29.803499, -109.68)
# ('NACO', 31.3262, -109.947083)
# ('NACORI CHICO', 29.687731, -108.980827)
# ('NACOZARI DE GARCIA', 30.375521, -109.688629)
# ('NAVOJOA', 27.07324, -109.443741)
# ('NOGALES', 31.301809, -110.938454)
# ('ONAVAS', 28.460951, -109.528511)
# ('OPODEPE', 29.925859, -110.628487)
# ('OQUITOA', 30.741671, -111.733612)
# ('PITIQUITO', 30.678089, -112.054863)
# ('PUERTO PEÑASCO', 31.32707, -113.53669)
# ('QUIRIEGO', 27.52072, -109.253151)
# ('RAYON', 29.7131, -110.57)
# ('ROSARIO', 27.844, -109.371002)
# ('SAHUARIPA', 29.0543, -109.233414)
# ('SAN FELIPE DE JESUS', 29.8587, -110.240028)
# ('SAN IGNACIO RIO MUERTO', 27.41243, -110.244583)
# ('SAN JAVIER', 28.59549, -109.740677)
# ('SAN LUIS RIO COLORADO', 32.452862, -114.77179)
# ('SAN MIGUEL DE HORCASITAS', 29.48736, -110.725021)
# ('SAN PEDRO DE LA CUEVA', 29.28731, -109.736259)
# ('SANTA ANA', 30.539801, -111.120003)
# ('SANTA CRUZ', 31.23245, -110.596252)
# ('SARIC', 31.10401, -111.378838)
# ('SOYOPA', 28.763941, -109.635147)
# ('SUAQUI GRANDE', 28.395411, -109.889137)
# ('TEPACHE', 29.532551, -109.531059)
# ('TRINCHERAS', 30.39699, -111.527992)
# ('TUBUTAMA', 30.884211, -111.462608)
# ('URES', 29.42618, -110.386108)
# ('VILLA HIDALGO', 30.16073, -109.320557)
# ('VILLA PESQUEIRA', 29.11796, -109.96711)
# ('YECORA', 28.37175, -108.926979)

# %% [markdown]
# # Poblacion
# Realizamos el proceso anterior de manera analogo para los datos de la poblacion

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mcd-unison/ing-caract/main/ejemplos/mapas/python/POBLACION_SONORA2020.csv')
df.head()
# Out:
#                   JURISDICCION SANITARIA COORDINACION MEDICA LOCAL  \
# 0  JURISDICCION SANITARIA I - HERMOSILLO         CML 01 HERMOSILLO
# 1  JURISDICCION SANITARIA I - HERMOSILLO         CML 01 HERMOSILLO
# 2  JURISDICCION SANITARIA I - HERMOSILLO         CML 01 HERMOSILLO
# 3  JURISDICCION SANITARIA I - HERMOSILLO         CML 01 HERMOSILLO
# 4  JURISDICCION SANITARIA I - HERMOSILLO         CML 01 HERMOSILLO
#
#      MUNICIPIO  POBLACION TOTAL
# 0        CARBO             6261
# 1  LA COLORADA             1675
# 2   HERMOSILLO           914163
# 3      MAZATAN             1403
# 4       ONAVAS              421

# %%
df.dtypes
# Out:
# JURISDICCION SANITARIA       object
# COORDINACION MEDICA LOCAL    object
# MUNICIPIO                    object
# POBLACION TOTAL               int64
# dtype: object

# %%
try:#Mismo proceso para creacion de tablas que se realizo antes
    conn = msql.connect(host='localhost',
                           database='sonora', user='root',
                           password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("Estas coenctado a: ", record)
        cursor.execute('DROP TABLE IF EXISTS poblacion;')
        print('Creado tabla poblacion...')
        cursor.execute(f"""CREATE TABLE poblacion (
                        jurisdiccion_sanitaria CHAR(100) NOT NULL,
                        coord_medica_local CHAR(100) NOT NULL, 
                        municipio CHAR(100) NOT NULL, 
                        poblacion INT NOT NULL)""")
        print("La tabla coordenada fue creada...")
        for i,row in df.iterrows():
            sql = "INSERT INTO sonora.poblacion VALUES (%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            # the connection is not autocommitted by default, so we must commit to save our changes
            conn.commit()
        print('Operacion exitosa')
except Error as e:
    print("Error al conectarse: ", e)
# Out:
# Estas coenctado a:  ('sonora',)
# Creado tabla poblacion...
# La tabla coordenada fue creada...
# Operacion exitosa

# %%
# Execute query
sql = "SELECT * FROM poblacion"
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 01 HERMOSILLO', 'CARBO', 6261)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 01 HERMOSILLO', 'LA COLORADA', 1675)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 01 HERMOSILLO', 'HERMOSILLO', 914163)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 01 HERMOSILLO', 'MAZATAN', 1403)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 01 HERMOSILLO', 'ONAVAS', 421)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 01 HERMOSILLO', 'SAN JAVIER', 745)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 01 HERMOSILLO', 'SAN MIGUEL DE HORCASITAS', 10939)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 01 HERMOSILLO', 'SAN PEDRO DE LA CUEVA', 1815)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 01 HERMOSILLO', 'SOYOPA', 1373)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 01 HERMOSILLO', 'SUAQUI GRANDE', 1171)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 01 HERMOSILLO', 'VILLA PESQUEIRA', 1242)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 02 URES', 'ACONCHI', 2928)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 02 URES', 'BANAMICHI', 1836)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 02 URES', 'BAVIACORA', 3816)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 02 URES', 'HUEPAC', 1271)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 02 URES', 'OPODEPE', 3177)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 02 URES', 'RAYON', 1680)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 02 URES', 'SAN FELIPE DE JESUS', 483)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 02 URES', 'URES', 10243)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 03 SAHUARIPA', 'ARIVECHI', 1304)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 03 SAHUARIPA', 'BACANORA', 814)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 03 SAHUARIPA', 'SAHUARIPA', 6512)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 04 MOCTEZUMA', 'BACADEHUACHI', 1285)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 04 MOCTEZUMA', 'CUMPAS', 7162)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 04 MOCTEZUMA', 'DIVISADEROS', 970)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 04 MOCTEZUMA', 'GRANADOS', 1340)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 04 MOCTEZUMA', 'HUASABAS', 1061)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 04 MOCTEZUMA', 'MOCTEZUMA', 5296)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 04 MOCTEZUMA', 'NACORI CHICO', 2374)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 04 MOCTEZUMA', 'NACOZARI DE GARCIA', 14419)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 04 MOCTEZUMA', 'TEPACHE', 1552)
# ('JURISDICCION SANITARIA I - HERMOSILLO', 'CML 04 MOCTEZUMA', 'VILLA HIDALGO', 1952)
# ('JURISDICCION SANITARIA II - CABORCA', 'CML 07 CABORCA', 'ALTAR', 10232)
# ('JURISDICCION SANITARIA II - CABORCA', 'CML 07 CABORCA', 'ATIL', 593)
# ('JURISDICCION SANITARIA II - CABORCA', 'CML 07 CABORCA', 'CABORCA', 96017)
# ('JURISDICCION SANITARIA II - CABORCA', 'CML 07 CABORCA', 'OQUITOA', 496)
# ('JURISDICCION SANITARIA II - CABORCA', 'CML 07 CABORCA', 'PITIQUITO', 10462)
# ('JURISDICCION SANITARIA II - CABORCA', 'CML 07 CABORCA', 'SARIC', 2975)
# ('JURISDICCION SANITARIA II - CABORCA', 'CML 07 CABORCA', 'TUBUTAMA', 1822)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 08 SANTA ANA', 'BENJAMIN HILL', 5630)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 08 SANTA ANA', 'SANTA ANA', 18247)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 08 SANTA ANA', 'TRINCHERAS', 1856)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 09 MAGDALENA', 'CUCURPE', 1110)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 09 MAGDALENA', 'IMURIS', 14577)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 09 MAGDALENA', 'MAGDALENA', 35093)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 10 NOGALES', 'NOGALES', 257894)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 11 CANANEA', 'ARIZPE', 3259)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 11 CANANEA', 'BACOACHI', 1890)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 11 CANANEA', 'CANANEA', 36066)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 11 CANANEA', 'SANTA CRUZ', 2277)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 12 AGUA PRIETA', 'AGUA PRIETA', 92364)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 12 AGUA PRIETA', 'BACERAC', 1668)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 12 AGUA PRIETA', 'BAVISPE', 1633)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 12 AGUA PRIETA', 'FRONTERAS', 10110)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 12 AGUA PRIETA', 'HUACHINERA', 1516)
# ('JURISDICCION SANITARIA III - SANTA ANA', 'CML 12 AGUA PRIETA', 'NACO', 7166)
# ('JURISDICCION SANITARIA IV - OBREGON', 'CML 13 GUAYMAS', 'EMPALME', 60892)
# ('JURISDICCION SANITARIA IV - OBREGON', 'CML 13 GUAYMAS', 'GUAYMAS', 172317)
# ('JURISDICCION SANITARIA IV - OBREGON', 'CML 15 OBREGON', 'BACUM', 25855)
# ('JURISDICCION SANITARIA IV - OBREGON', 'CML 15 OBREGON', 'CAJEME', 468442)
# ('JURISDICCION SANITARIA IV - OBREGON', 'CML 15 OBREGON', 'QUIRIEGO', 3704)
# ('JURISDICCION SANITARIA IV - OBREGON', 'CML 15 OBREGON', 'ROSARIO', 5566)
# ('JURISDICCION SANITARIA IV - OBREGON', 'CML 15 OBREGON', 'YECORA', 6451)
# ('JURISDICCION SANITARIA IV - OBREGON', 'CML 15 OBREGON', 'SAN IGNACIO RIO MUERTO', 15802)
# ('JURISDICCION SANITARIA V - NAVOJOA', 'CML 16 NAVOJOA', 'ETCHOJOA', 68718)
# ('JURISDICCION SANITARIA V - NAVOJOA', 'CML 16 NAVOJOA', 'NAVOJOA', 179823)
# ('JURISDICCION SANITARIA V - NAVOJOA', 'CML 16 NAVOJOA', 'BENITO JUAREZ', 24744)
# ('JURISDICCION SANITARIA V - NAVOJOA', 'CML 17 HUATABAMPO', 'HUATABAMPO', 88568)
# ('JURISDICCION SANITARIA V - NAVOJOA', 'CML 18 ALAMOS', 'ALAMOS', 28461)
# ('JURISDICCION SANITARIA VI - SAN LUIS RIO COLORADO', 'CML 05 SAN LUIS RIO COLORADO', 'SAN LUIS RIO COLORADO', 207440)
# ('JURISDICCION SANITARIA VI - SAN LUIS RIO COLORADO', 'CML 06 PUERTO PEÑASCO', 'PUERTO PEÑASCO', 71208)
# ('JURISDICCION SANITARIA VI - SAN LUIS RIO COLORADO', 'CML 06 PUERTO PEÑASCO', 'GENERAL PLUTARCO ELIAS CALLES', 19118)

# %%
# Close the connection
if (conn.is_connected()):
    cursor.close()
    conn.close()
    print("MySQL cerrada")
# Out:
# MySQL cerrada

# %% [markdown]
# # Leyendo lo que escribimos
# Creamos un conector que sera usado por pandas

# %%
try:
    mydb = msql.connect(host="localhost", database = 'sonora',user="root", passwd="root",use_pure=True)
    query_pob = "Select * from poblacion;"
    municipios_poblacion  = pd.read_sql(query_pob,mydb)
    query_mun = "Select * from coordenada;"
    municipios = pd.read_sql(query_mun,mydb)
    mydb.close() #close the connection
except Exception as e:
    mydb.close()
    print(str(e))

# %%
municipios = municipios.merge(municipios_poblacion, on="municipio") 

municipios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72 entries, 0 to 71
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   municipio               72 non-null     object
#  1   latitud                 72 non-null     float64
#  2   longitud                72 non-null     float64
#  3   jurisdiccion_sanitaria  72 non-null     object
#  4   coord_medica_local      72 non-null     object
#  5   poblacion               72 non-null     int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.9+ KB

# %%
try:
    mydb = msql.connect(host="localhost", database = 'sonora',user="root", passwd="root",use_pure=True)
    query = f"""SELECT c.municipio, c.latitud,c.longitud,
                        p.jurisdiccion_sanitaria,p.coord_medica_local, p.poblacion 
                        FROM coordenada c INNER JOIN poblacion p ON p.municipio = c.municipio;"""
    municipios_join  = pd.read_sql(query,mydb)
    mydb.close() #close the connection
except Exception as e:
    mydb.close()
    print(str(e))

# %%
municipios_join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   municipio               72 non-null     object
#  1   latitud                 72 non-null     float64
#  2   longitud                72 non-null     float64
#  3   jurisdiccion_sanitaria  72 non-null     object
#  4   coord_medica_local      72 non-null     object
#  5   poblacion               72 non-null     int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.5+ KB

# %%
municipios_join = municipios_join.sort_values(by=['municipio']).reset_index(drop=True)

# %% [markdown]
# Despues de una ordenada, podemos observar que los resulados son equivalentes

# %%
municipios_join.head()
# Out:
#      municipio    latitud    longitud                  jurisdiccion_sanitaria  \
# 0      ACONCHI  29.825420 -110.208397   JURISDICCION SANITARIA I - HERMOSILLO
# 1  AGUA PRIETA  31.330048 -109.549042  JURISDICCION SANITARIA III - SANTA ANA
# 2       ALAMOS  27.026819 -108.925598      JURISDICCION SANITARIA V - NAVOJOA
# 3        ALTAR  30.715071 -111.821350     JURISDICCION SANITARIA II - CABORCA
# 4     ARIVECHI  29.078529 -109.195831   JURISDICCION SANITARIA I - HERMOSILLO
#
#    coord_medica_local  poblacion
# 0         CML 02 URES       2928
# 1  CML 12 AGUA PRIETA      92364
# 2       CML 18 ALAMOS      28461
# 3      CML 07 CABORCA      10232
# 4    CML 03 SAHUARIPA       1304

# %%
municipios.head()
# Out:
#      municipio    latitud    longitud                  jurisdiccion_sanitaria  \
# 0      ACONCHI  29.825420 -110.208397   JURISDICCION SANITARIA I - HERMOSILLO
# 1  AGUA PRIETA  31.330048 -109.549042  JURISDICCION SANITARIA III - SANTA ANA
# 2       ALAMOS  27.026819 -108.925598      JURISDICCION SANITARIA V - NAVOJOA
# 3        ALTAR  30.715071 -111.821350     JURISDICCION SANITARIA II - CABORCA
# 4     ARIVECHI  29.078529 -109.195831   JURISDICCION SANITARIA I - HERMOSILLO
#
#    coord_medica_local  poblacion
# 0         CML 02 URES       2928
# 1  CML 12 AGUA PRIETA      92364
# 2       CML 18 ALAMOS      28461
# 3      CML 07 CABORCA      10232
# 4    CML 03 SAHUARIPA       1304

# %% [markdown]
# # Haciendo mapas con folium

# %%
#!conda install folium -c conda-forge -y

# %%
# Creando un mapa sólo para ver:

import folium

m = folium.Map(
    location=(29.66667, -110.5),
    tiles='OpenStreetMap',
    zoom_start=7,
    min_zoom=4,
    max_zoom=12,
    width='80%',
    height='80'
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7671839949c4392ec9cc36335d4aa4af {
#                     position: relative;
#                     width: 80.0%;
#                     height: 80.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7671839949c4392ec9cc36335d4aa4af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7671839949c4392ec9cc36335d4aa4af = L.map(
#                 &quot;map_7671839949c4392ec9cc36335d4aa4af&quot;,
#                 {
#                     center: [29.66667, -110.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23fa50970d7aaf0dfd45075495fb69bc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 12, &quot;maxZoom&quot;: 12, &quot;minZoom&quot;: 4, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7671839949c4392ec9cc36335d4aa4af);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map(
    location=(29.66667, -110.5),
    tiles='OpenStreetMap',
    zoom_start=7,
    min_zoom=4,
    max_zoom=12,
)


for row in municipios.itertuples():
    folium.Marker(
        location=[row.latitud, row.longitud],
        tooltip=f"{row.municipio} Población: {row.poblacion} habitantes",
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d02ab52f4372a8f6a52dbf02fdc77ce1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d02ab52f4372a8f6a52dbf02fdc77ce1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d02ab52f4372a8f6a52dbf02fdc77ce1 = L.map(
#                 &quot;map_d02ab52f4372a8f6a52dbf02fdc77ce1&quot;,
#                 {
#                     center: [29.66667, -110.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9681c8ee084728e85966495ff9fbd77 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 12, &quot;maxZoom&quot;: 12, &quot;minZoom&quot;: 4, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d02ab52f4372a8f6a52dbf02fdc77ce1);
#
#
#             var marker_1f1e13543556126c15fafe1d8d76c97c = L.marker(
#                 [29.82542, -110.208397],
#                 {}
#             ).addTo(map_d02ab52f4372a8f6a52dbf02fdc77ce1);
#
#
#             marker_1f1e13543556126c15fafe1d8d76c97c.bindTooltip(
#                 `&lt;div&gt;
#                      ACONCHI Población: 2928 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5e462a3b8ca1d3c5baa631273b737c57 = L.marker(
#                 [31.330048, -109.549042],
#                 {}
#             ).addTo(map_d02ab52f4372a8f6a52dbf02fdc77ce1);
#
#
#             marker_5e462a3b8ca1d3c5baa631273b737c57.bindTooltip(
#                 `&lt;div&gt;
#                      AGUA PRIETA Población: 92364 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_67118804e576139a96284882c6521c0c = L.marker(
#                 [27.026819, -108.925598],
#                 {}
#             ).addTo(map_d02ab52f4372a8f6a52dbf02fdc77ce1);
#
#
#             marker_67118804e576139a96284882c6521c0c.bindTooltip(
#                 `&lt;div&gt;
#                      ALAMOS Población: 28461 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2596571c9a3d2cb042c742d618588000 = L.marker(
#                 [30.715071, -111.82135],
#                 {}
#             ).addTo(map_d02ab52f4372a8f6a52dbf02fdc77ce1);
#
#
#             marker_2596571c9a3d2cb042c742d618588000.bindTooltip(
#                 `&lt;div&gt;
#                      ALTAR Población: 10232 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_301af0b1f7c38e252c8678be4273b769 = L.marker(
#                 [29.078529, -109.195831],
#                 {}
#             ).addTo(map_d02ab52f4372a8f6a52dbf02fdc77ce1);
#
#
#             marker_301af0b1f7c38e252c8678be4273b769.bindTooltip(
#                 `&lt;div&gt;
#                      ARIVECHI Población: 1304 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e39363d1cbcd16a254bfd0f8329884e0 = L.marker(
#                 [30.40764, -110.164749],
#                 {}
#             ).addTo(map_d02ab52f4372a8f6a52dbf02fdc77ce1);
#
#
#             marker_e39363d1cbcd16a254bfd0f8329884e0.bindTooltip(
#                 `&lt;div&gt;
#                      ARIZPE Población: 3259 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_028aa4c1b242fdbb958cd06eaba411f3 = L.marker(
#                 [30.884211, -111.582779],
#                 {}
#             ).addTo(map_d02ab52f4372a8f6a52dbf02fdc77ce1);
#
#
#             marker_028aa4c1b242fdbb958cd06eaba411f3.bindTooltip(
#                 `&lt;div&gt;
#                      ATIL Población: 593 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0aeabfe81cab7e5393ed418f6369a8a6 = L.marker(
#                 [29.81189, -109.140793],
#                 {}
#             ).addTo(map_d02ab52f4372a8f6a52dbf02fdc77ce1);
#
#
#             marker_0aeabfe81cab7e5393ed418f6369a8a6.bindTooltip(
#                 `&lt;div&gt;
#                      BACADEHUACHI Población: 1285 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2850151252867c210d57688d66bdc683 = L.marker(
#                 [28.98597, -109.400398],
#                 {}
#             ).addTo(map_d02ab52f4372a8f6a52dbf02fdc77ce1);
#
#
#             marker_2850151252867c210d57688d66bdc683.bindTooltip(
#                 `&lt;div&gt;
#                      BACANORA Población: 814 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e9b5dc1e135e723a3c505e08b0cf30b2 = L.marker(
#                 [30.50449, -108.924011]

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=(29.66667, -110.5),
    tiles='OpenStreetMap',
    zoom_start=7,
    min_zoom=4,
    max_zoom=12,
)

grupo = MarkerCluster().add_to(m)

for row in municipios.itertuples():
    folium.Marker(
        location=[row.latitud, row.longitud],
        tooltip=f"{row.municipio} Población: {row.poblacion} habitantes",
    ).add_to(grupo)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80e7d4063255d81b40e5b1bf698cab99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80e7d4063255d81b40e5b1bf698cab99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80e7d4063255d81b40e5b1bf698cab99 = L.map(
#                 &quot;map_80e7d4063255d81b40e5b1bf698cab99&quot;,
#                 {
#                     center: [29.66667, -110.5],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8441d55d250c0de2747a16b4b7a278e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 12, &quot;maxZoom&quot;: 12, &quot;minZoom&quot;: 4, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_80e7d4063255d81b40e5b1bf698cab99);
#
#
#             var marker_cluster_7120cbbc7e18915a03446809ec03703e = L.markerClusterGroup(
#                 {}
#             );
#             map_80e7d4063255d81b40e5b1bf698cab99.addLayer(marker_cluster_7120cbbc7e18915a03446809ec03703e);
#
#
#             var marker_b37ee0f77aaff62658a212274f9d5fac = L.marker(
#                 [29.82542, -110.208397],
#                 {}
#             ).addTo(marker_cluster_7120cbbc7e18915a03446809ec03703e);
#
#
#             marker_b37ee0f77aaff62658a212274f9d5fac.bindTooltip(
#                 `&lt;div&gt;
#                      ACONCHI Población: 2928 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e7548af4dce96b5df843b6341f3d5aeb = L.marker(
#                 [31.330048, -109.549042],
#                 {}
#             ).addTo(marker_cluster_7120cbbc7e18915a03446809ec03703e);
#
#
#             marker_e7548af4dce96b5df843b6341f3d5aeb.bindTooltip(
#                 `&lt;div&gt;
#                      AGUA PRIETA Población: 92364 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b3f6f167f9aec18562bdc765724a535c = L.marker(
#                 [27.026819, -108.925598],
#                 {}
#             ).addTo(marker_cluster_7120cbbc7e18915a03446809ec03703e);
#
#
#             marker_b3f6f167f9aec18562bdc765724a535c.bindTooltip(
#                 `&lt;div&gt;
#                      ALAMOS Población: 28461 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fee678f625c98a0e6c8ca25a251bc3ee = L.marker(
#                 [30.715071, -111.82135],
#                 {}
#             ).addTo(marker_cluster_7120cbbc7e18915a03446809ec03703e);
#
#
#             marker_fee678f625c98a0e6c8ca25a251bc3ee.bindTooltip(
#                 `&lt;div&gt;
#                      ALTAR Población: 10232 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cb0cac9af88f2d39ef90936df138ebfe = L.marker(
#                 [29.078529, -109.195831],
#                 {}
#             ).addTo(marker_cluster_7120cbbc7e18915a03446809ec03703e);
#
#
#             marker_cb0cac9af88f2d39ef90936df138ebfe.bindTooltip(
#                 `&lt;div&gt;
#                      ARIVECHI Población: 1304 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_23c5ea35f251c2d8cc2c799f2c86fa45 = L.marker(
#                 [30.40764, -110.164749],
#                 {}
#             ).addTo(marker_cluster_7120cbbc7e18915a03446809ec03703e);
#
#
#             marker_23c5ea35f251c2d8cc2c799f2c86fa45.bindTooltip(
#                 `&lt;div&gt;
#                      ARIZPE Población: 3259 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4029c97d506302fb3b8c617d7b4bffc7 = L.marker(
#                 [30.884211, -111.582779],
#                 {}
#             ).addTo(marker_cluster_7120cbbc7e18915a03446809ec03703e);
#
#
#             marker_4029c97d506302fb3b8c617d7b4bffc7.bindTooltip(
#                 `&lt;div&gt;
#                      ATIL Población: 593 habitantes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7be73b363c68541670fa8de9f515d800 = L.marker(
#                 [29.81189, -109.140793],
#                 {}
#             ).addTo(marker_cluster_7120cbbc7e18915a03446809ec03703e);
#
#
#             marker_7be73b363c68541670fa8de9f5

# %% [markdown]
# # Creating a view

# %%
try:
    conn = msql.connect(host='localhost',
                           database='sonora', user='root',
                           password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("Estas coenctado a: ", record)
        cursor.execute('DROP VIEW IF EXISTS vw_mapa;')
        print('Creado tabla poblacion...')
        cursor.execute(f"""CREATE VIEW vw_mapa AS
                               SELECT c.municipio, c.latitud,c.longitud,
                                      p.jurisdiccion_sanitaria,p.coord_medica_local, p.poblacion 
                               FROM coordenada c INNER JOIN poblacion p ON p.municipio = c.municipio
                               ORDER BY municipio
                               ;
        """)
        print("La vista vw_mapa fue creada...")
        print('Operacion exitosa')
except Error as e:
    print("Error al conectarse: ", e)
# Out:
# Estas coenctado a:  ('sonora',)
# Creado tabla poblacion...
# La vista vw_mapa fue creada...
# Operacion exitosa

# %%
try:
    query_pob = "Select * from vw_mapa;"
    municipios  = pd.read_sql(query_pob,conn)
except Exception as e:
    print(str(e))

# %%
municipios.head()
# Out:
#      municipio    latitud    longitud                  jurisdiccion_sanitaria  \
# 0      ACONCHI  29.825420 -110.208397   JURISDICCION SANITARIA I - HERMOSILLO
# 1  AGUA PRIETA  31.330048 -109.549042  JURISDICCION SANITARIA III - SANTA ANA
# 2       ALAMOS  27.026819 -108.925598      JURISDICCION SANITARIA V - NAVOJOA
# 3        ALTAR  30.715071 -111.821350     JURISDICCION SANITARIA II - CABORCA
# 4     ARIVECHI  29.078529 -109.195831   JURISDICCION SANITARIA I - HERMOSILLO
#
#    coord_medica_local  poblacion
# 0         CML 02 URES       2928
# 1  CML 12 AGUA PRIETA      92364
# 2       CML 18 ALAMOS      28461
# 3      CML 07 CABORCA      10232
# 4    CML 03 SAHUARIPA       1304

# %%
# Close the connection
if (conn.is_connected()):
    cursor.close()
    conn.close()
    print("MySQL cerrada")
# Out:
# MySQL cerrada

# %% [markdown]
# # Creating a function

# %% [markdown]
# Por fines didacticos esto lo haremos de manera manual mediante la linea de comandos.
# ```SQL
# DROP FUNCTION IF EXISTS fn_get_poblacion_jurisdiccion
# DELIMITER //
# CREATE FUNCTION sonora.fn_get_poblacion_jurisdiccion(jurisdiccion CHAR(200))
# RETURNS INT
# DETERMINISTIC
# BEGIN
#    declare jur_poblacion INT;
#    SELECT SUM(poblacion) INTO jur_poblacion
#    FROM vw_mapa WHERE jurisdiccion_sanitaria = jurisdiccion;
#    RETURN jur_poblacion;
# END //
# DELIMITER ;
# ```

# %%
try:
    conn = msql.connect(host='localhost',
                           database='sonora', user='root',
                           password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("Estas coenctado a: ", record)
        query_pob_hermosillo = "Select fn_get_poblacion_jurisdiccion('JURISDICCION SANITARIA I - HERMOSILLO');"
        poblacion_hermosillo  = pd.read_sql(query_pob_hermosillo,conn)
        query_pob_santaana = "Select fn_get_poblacion_jurisdiccion('JURISDICCION SANITARIA III - SANTA ANA');"
        poblacion_santaana  = pd.read_sql(query_pob_santaana,conn)
        print('Operacion exitosa')
except Error as e:
    print("Error al conectarse: ", e)
# Out:
# Estas coenctado a:  ('sonora',)
# Operacion exitosa

# %%
poblacion_santaana
# Out:
#    fn_get_poblacion_jurisdiccion('JURISDICCION SANITARIA III - SANTA ANA')
# 0                                             492356

# %%
poblacion_hermosillo
# Out:
#    fn_get_poblacion_jurisdiccion('JURISDICCION SANITARIA I - HERMOSILLO')
# 0                                            1012683

# %%
# Close the connection
if (conn.is_connected()):
    cursor.close()
    conn.close()
    print("MySQL cerrada")
# Out:
# MySQL cerrada

# %% [markdown]
# # Creating a procedure

# %% [markdown]
# ```SQL
# DELIMITER $$
# CREATE PROCEDURE fn_get_poblacion_coord_medica(IN coord CHAR(200))
# BEGIN
# SELECT
#    SUM(poblacion) AS poblacion_coord
#    FROM vw_mapa WHERE coord_medica_local = coord;
# END $$
# DELIMITER ;
# ```

# %%
try:
    conn = msql.connect(host='localhost',
                           database='sonora', user='root',
                           password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("Estas coenctado a: ", record)
        query_pob_caborca = "CALL fn_get_poblacion_coord_medica('CML 07 CABORCA');"
        poblacion_caborca  = pd.read_sql(query_pob_caborca,conn)
        print('Operacion exitosa')
except Error as e:
    print("Error al conectarse: ", e)
# Out:
# Estas coenctado a:  ('sonora',)
# Operacion exitosa

# %%
poblacion_caborca
# Out:
#    SUM(poblacion)
# 0        122597.0

# %% [markdown]
# ## Exportando la base de datos.
#
# Por ultimo usamos los comando que se usarian en la consola del sistema para exportar la base de datos.

# %%
import os
os.system('mysql -u root -p%s sonora > sonora.sql' % 'root')
# Out:
# mysql: [Warning] Using a password on the command line interface can be insecure.
# 0
